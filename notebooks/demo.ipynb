# %%
import sys, os
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from scripts.interactive import build_lorenz_dashboard
ui = build_lorenz_dashboard()
ui

# %%
import sys, os
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from scripts.lorenz_system import solve_lorenz
from scripts.plotting import plot_3d, plot_projections, plot_time_series
import matplotlib.pyplot as plt

# %%
t, y = solve_lorenz(sigma=10, rho=28, beta=8/3, n_points=20000)
x, Y, z = y

ax = plot_3d(x, Y, z, title="Lorenz (σ=10, ρ=28, β=8/3)")
plt.savefig("../images/lorenz_default.png", dpi=300, bbox_inches="tight")

plot_projections(x, Y, z)
plt.savefig("../images/lorenz_projections.png", dpi=300, bbox_inches="tight")

plot_time_series(t, x, Y, z)
plt.savefig("../images/lorenz_timeseries.png", dpi=300, bbox_inches="tight")
